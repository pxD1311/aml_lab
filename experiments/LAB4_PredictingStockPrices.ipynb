# %% [markdown]
# PREDICTIN STOCK PRICES: Develop a time series

# %%
import yfinance as yf
data = yf.download("AAPL", start = "2018-01-01", end = "2026-02-04")
# Out:
# /tmp/ipython-input-2206552741.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("AAPL", start = "2018-01-01", end = "2026-02-04")
# [*********************100%***********************]  1 of 1 completed

# %%
print (data.head(10))
# Out:
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2018-01-02  40.341885  40.351254  39.639309  39.850084  102223600
# 2018-01-03  40.334869  40.878196  40.271640  40.405128  118071600
# 2018-01-04  40.522221  40.625266  40.299739  40.407465   89738400
# 2018-01-05  40.983582  41.070231  40.526908  40.618243   94640000
# 2018-01-08  40.831356  41.126437  40.732992  40.831356   82271200
# 2018-01-09  40.826664  40.997623  40.611208  40.878186   86336000
# 2018-01-10  40.817303  40.819647  40.515197  40.552668   95839600
# 2018-01-11  41.049149  41.098330  40.864139  40.887556   74670800
# 2018-01-12  41.473038  41.536271  41.135801  41.259922  101672400
# 2018-01-16  41.262268  42.011681  41.250558  41.662734  118263600

# %%
print (data.tail(10))
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2026-01-21  247.649994  251.559998  245.179993  248.699997  54641700
# 2026-01-22  248.350006  251.000000  248.149994  249.199997  39708300
# 2026-01-23  248.039993  249.410004  244.679993  247.320007  41689000
# 2026-01-26  255.410004  256.559998  249.800003  251.479996  55969200
# 2026-01-27  258.269989  261.950012  258.209991  259.170013  49648300
# 2026-01-28  256.440002  258.859985  254.509995  257.649994  41288000
# 2026-01-29  258.279999  259.649994  254.410004  258.000000  67253000
# 2026-01-30  259.480011  261.899994  252.179993  255.169998  92443400
# 2026-02-02  270.010010  270.489990  259.209991  260.029999  73913400
# 2026-02-03  269.480011  271.880005  267.609985  269.200012  64339600

# %%
data.isna().sum()
# isna:: Creates a True/False table
# Out:
# Price   Ticker
# Close   AAPL      0
# High    AAPL      0
# Low     AAPL      0
# Open    AAPL      0
# Volume  AAPL      0
# dtype: int64

# %%
df = data.copy()
df
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2018-01-02   40.341885   40.351254   39.639309   39.850084  102223600
# 2018-01-03   40.334869   40.878196   40.271640   40.405128  118071600
# 2018-01-04   40.522221   40.625266   40.299739   40.407465   89738400
# 2018-01-05   40.983582   41.070231   40.526908   40.618243   94640000
# 2018-01-08   40.831356   41.126437   40.732992   40.831356   82271200
# ...                ...         ...         ...         ...        ...
# 2026-01-28  256.440002  258.859985  254.509995  257.649994   41288000
# 2026-01-29  258.279999  259.649994  254.410004  258.000000   67253000
# 2026-01-30  259.480011  261.899994  252.179993  255.169998   92443400
# 2026-02-02  270.010010  270.489990  259.209991  260.029999   73913400
# 2026-02-03  269.480011  271.880005  267.609985  269.200012   64339600
#
# [2033 rows x 5 columns]

# %% [markdown]
# LAG1 : 1 day before price
#
# LAG2 : 2 day before price
#
# LAGn : n day before price
#
#         x(feature)        y
# lag1 lag2 lag 3      close(today)

# %%
df['Lag1'] = df['Close'].shift(1)
df['Lag2'] = df['Close'].shift(2)
df['Lag3'] = df['Close'].shift(3)

df.dropna(inplace= True)
df.head()

# To predict today’s Close price, I will use the Close prices from the last 3 days.
# Out:
# Price           Close       High        Low       Open    Volume       Lag1  \
# Ticker           AAPL       AAPL       AAPL       AAPL      AAPL
# Date
# 2018-01-05  40.983582  41.070231  40.526908  40.618243  94640000  40.522221
# 2018-01-08  40.831356  41.126437  40.732992  40.831356  82271200  40.983582
# 2018-01-09  40.826664  40.997623  40.611208  40.878186  86336000  40.831356
# 2018-01-10  40.817303  40.819647  40.515197  40.552668  95839600  40.826664
# 2018-01-11  41.049149  41.098330  40.864139  40.887556  74670800  40.817303
#
# Price            Lag2       Lag3
# Ticker
# Date
# 2018-01-05  40.334869  40.341885
# 2018-01-08  40.522221  40.334869
# 2018-01-09  40.983582  40.522221
# 2018-01-10  40.831356  40.983582
# 2018-01-11  40.826664  40.831356

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(df['Close'])
plt.xlabel("Time")
plt.ylabel("Close Price")
plt.title("Stock Close Price Over Time")
plt.show()

# %%
plt.scatter(df['Lag3'], df['Close'], alpha=0.7)

plt.xlabel("Lag3")
plt.ylabel("Close")
plt.title("Sill Strong Correlation but more distortion")
plt.show()

# %%
plt.scatter(df['Lag3'], df['Close'], alpha=0.2)

plt.xlabel("Lag3")
plt.ylabel("Close")
plt.title("Sill Strong Correlation but more distortion")
plt.show()

# %% [markdown]
# DEFINE X AND Y

# %%
X = df[['Lag1', 'Lag2', 'Lag3']]
y = df['Close']

# %% [markdown]
# TRAIN TEST SPLIT

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    shuffle=False
)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
plt.figure(figsize=(10,5))
plt.plot(y_test.values, label = 'Actual Price')
plt.plot(y_pred, label = 'Predicted Price')

plt.legend()
plt.title("Stock Price Prediction using Linear Regression")
plt.xlabel ("Time Index")
plt.ylabel("Price")
plt.show()
